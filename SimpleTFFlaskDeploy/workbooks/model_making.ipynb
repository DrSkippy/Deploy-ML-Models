# %% [markdown]
# # Simple Model Build Example
#
# 2022 June 08
#
# ### The Job is to predict level adult earnings per year based on demographic data
#
# Data we have available has many dimensions of data. Some numerical, some categoriecal.
#
# We have a training set with the inputs and truth-values for incomes above or below $50K based.
#
# ![alt text](../img/model_grid.png "Model Grid")

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

from model.training_data import *

# %matplotlib inline

# %% [markdown]
# # Investigate the available input data and the training data set

# %%
print(file_path)
# !ls $file_path
# Out:
# ../data/
# adult.data            decision_tree.pkl     neural_net.pkl
# adult.names           feature_vetting.csv   neural_net_scaler.pkl

# %% [markdown]
# ### These are the input vectors we have available...

# %%
header = get_header()
print("\n".join(header))
# Out:
# age
# workclass
# fnlwgt
# education
# education-num
# marital-status
# occupation
# relationship
# race
# sex
# capital-gain
# capital-loss
# hours-per-week
# native-country
# class

# %%
df = get_training_dataframe()
df.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# 3      Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4      Married-civ-spouse      Prof-specialty            Wife   Black
# 5      Married-civ-spouse     Exec-managerial            Wife   White
# 6   Married-spouse-absent       Other-service   Not-in-family   Black
# 7      Married-civ-spouse     Exec-managerial         Husband   White
# 8           Never-married      Prof-specialty   Not-in-family   White
# 9      Married-civ-spouse     Exec-managerial         Husband   White
#
#        sex  capital-gain  capital-loss  hours-per-week  native-country   class
# 0     Male          2174             0              40   United-States   <=50K
# 1     Male             0             0              13   United-States   <=50K
# 2     Male             0             0              40   United-States   <=50K
# 3     Male             0             0              40   United-States   <=50K
# 4   Female             0             0              40            Cuba   <=50K
# 5   Female             0             0              40   United-States   <=50K
# 6   Female             0             0              16         Jamaica   <=50K
# 7     Male             0             0              45   United-States    >50K
# 8   Female         14084             0              50   United-States    >50K
# 9     Male          5178             0              40   United-States    >50K

# %% [markdown]
# ### Explore the Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       48842 non-null  object
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  object
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  object
#  6   occupation      48842 non-null  object
#  7   relationship    48842 non-null  object
#  8   race            48842 non-null  object
#  9   sex             48842 non-null  object
#  10  capital-gain    48842 non-null  int64
#  11  capital-loss    48842 non-null  int64
#  12  hours-per-week  48842 non-null  int64
#  13  native-country  48842 non-null  object
#  14  class           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  48842.000000  4.884200e+04   48842.000000  48842.000000  48842.000000
# mean      38.643585  1.896641e+05      10.078089   1079.067626     87.502314
# std       13.710510  1.056040e+05       2.570973   7452.019058    403.004552
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.175505e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.781445e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.376420e+05      12.000000      0.000000      0.000000
# max       90.000000  1.490400e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    48842.000000
# mean        40.422382
# std         12.391444
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
for h in header:
    n = len(df[h].value_counts())
    if n < 20:
        print("#"*25)
        print(f"{h}: {n}")
        print(df[h].value_counts())
        print("-"*20)
        print(df[h].describe())
# Out:
# #########################
# workclass: 9
#  Private             33906
#  Self-emp-not-inc     3862
#  Local-gov            3136
#  ?                    2799
#  State-gov            1981
#  Self-emp-inc         1695
#  Federal-gov          1432
#  Without-pay            21
#  Never-worked           10
# Name: workclass, dtype: int64
# --------------------
# count        48842
# unique           9
# top        Private
# freq         33906
# Name: workclass, dtype: object
# #########################
# education: 16
#  HS-grad         15784
#  Some-college    10878
#  Bachelors        8025
#  Masters          2657
#  Assoc-voc        2061
#  11th             1812
#  Assoc-acdm       1601
#  10th             1389
#  7th-8th           955
#  Prof-school       834
#  9th               756
#  12th              657
#  Doctorate         594
#  5th-6th           509
#  1st-4th           247
#  Preschool          83
# Name: education, dtype: int64
# --------------------
# count        48842
# unique          16
# top        HS-grad
# freq         15784
# Name: education, dtype: object
# #########################
# education-num: 16
# 9     15784
# 10    10878
# 13     8025
# 14     2657
# 11     2061
# 7      1812
# 12     1601
# 6      1389
# 4       955
# 15      834
# 5       756
# 8       657
# 16      594
# 3       509
# 2       247
# 1        83
# Name: education-num, dtype: int64
# --------------------
# count    48842.000000
# mean        10.078089
# std          2.570973
# min          1.000000
# 25%          9.000000
# 50%         10.000000
# 75%         12.000000
# max         16.000000
# Name: education-num, dtype: float64
# #########################
# marital-status: 7
#  Married-civ-spouse       22379
#  Never-married            16117
#  Divorced                  6633
#  Separated                 1530
#  Widowed                   1518
#  Married-spouse-absent      628
#  Married-AF-spouse           37
# Name: marital-status, dtype: int64
# --------------------
# count                   48842
# unique                      7
# top        Married-civ-spouse
# freq                    22379
# Name: marital-status, dtype: object
# #########################
# occupation: 15
#  Prof-specialty       6172
#  Craft-repair         6112
#  Exec-managerial      6086
#  Adm-clerical         5611
#  Sales                5504
#  Other-service        4923
#  Machine-op-inspct    3022
#  ?                    2809
#  Transport-moving     2355
#  Handlers-cleaners    2072
#  Farming-fishing      1490
#  Tech-support         1446
#  Protective-serv       983
#  Priv-house-serv       242
#  Armed-Forces           15
# Name: occupation, dtype: int64
# --------------------
# count               48842
# unique                 15
# top        Prof-specialty
# freq                 6172
# Name: occupation, dtype: object
# #########################
# relationship: 6
#  Husband           19716
#  Not-in-family     12583
#  Own-child          7581
#  Unmarried          5125
#  Wife               2331
#  Other-relative     1506
# Name: relationship, dtype: int64
# --------------------
# count        48842
# unique           6
# top        Husband
# freq         19716
# Name: relationship, dtype: object
# #########################
# race: 5
#  White                 41762
#  Black                  4685
#  Asian-Pac-Islander     1519
#  Amer-Indian-Eskimo      470
#  Other                   406
# Name: race, dtype: int64
# --------------------
# count      48842
# unique         5
# top        White
# freq       41762
# Name: race, dtype: object
# #########################
# sex: 2
#  Male      32650
#  Female    16192
# Name: sex, dtype: int64
# --------------------
# count     48842
# unique        2
# top        Male
# freq      32650
# Name: sex, dtype: object
# #########################
# class: 2
#  <=50K    37155
#  >50K     11687
# Name: class, dtype: int64
# --------------------
# count      48842
# unique         2
# top        <=50K
# freq       37155
# Name: class, dtype: object

# %% [markdown]
# ### Encoding classes will help a classifiers include inforamtion
# Start with an easy one...Sex in this data set has only 2 values.

# %%
# input encodings
df["sex-val"] = df["sex"].apply(lambda x: 1 if "M" in x else 0)
df[["sex", "sex-val"]].head(10)
# Out:
#        sex  sex-val
# 0     Male        1
# 1     Male        1
# 2     Male        1
# 3     Male        1
# 4   Female        0
# 5   Female        0
# 6   Female        0
# 7     Male        1
# 8   Female        0
# 9     Male        1

# %% [markdown]
# # Start with a simple and naive model

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ### What is highly correlated with income?
#
# * sex
# * age

# %%
dflr = df[["age", "sex-val"]].copy()
dflr.head()
# Out:
#    age  sex-val
# 0   39        1
# 1   50        1
# 2   38        1
# 3   53        1
# 4   28        0

# %%
class_train = df["class"].apply(lambda x: 1 if ">" in x else 0 )
class_train
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 48837    0
# 48838    0
# 48839    0
# 48840    0
# 48841    1
# Name: class, Length: 48842, dtype: int64

# %%
# Create linear regression object
regr = linear_model.LogisticRegression()

# Train the model using the training sets
regr.fit(dflr, class_train)

# Make predictions using the testing set
class_pred = regr.predict(dflr)

# %%
print('Accuracy of logistic regression classifier on the training set: {:.2f}%'.format(
    100*regr.score(dflr, class_train)))
# Out:
# Accuracy of logistic regression classifier on the training set: 74.45%

# %%
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(class_train, class_pred))
# Out:
# Mean squared error: 0.26

# %% [markdown]
# ![alt text](../img/boundary.jpg "Model Boundary")

# %% [markdown]
# # We can do better... Start modeling with numerically or encoded or continuous data vectors

# %%
print(features)
dft = df[features].copy()
y = df["class"]
# Out:
# ['age', 'fnlwgt', 'sex-val', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn import tree

# %% [markdown]
# ### Testing and Training sets help us evaluate performance
#
# ![alt text](../img/test_train_split.png "Test Train Split")

# %%
X_train, X_test, y_train, y_test = train_test_split(dft, y)

# %%
dec_tree=DecisionTreeClassifier().fit(X_train, y_train)
a = dec_tree.score(X_test, y_test)
print('Accuracy is: %', a*100)
# Out:
# Accuracy is: % 78.53574645811155

# %%
y_preds = dec_tree.predict(X_test)
print(classification_report(y_test, y_preds))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.86      0.85      0.86      9333
#         >50K       0.54      0.56      0.55      2878
#
#     accuracy                           0.79     12211
#    macro avg       0.70      0.71      0.71     12211
# weighted avg       0.79      0.79      0.79     12211

# %% [markdown]
# ### Let's look at the decision tree...
#
# High dimensionality, so maybe too complex to be explanatory? Also, maybe generate some skepticism on how will it will generalize?

# %%
text_representation = tree.export_text(dec_tree)
print(text_representation)
# Out:
# |--- feature_4 <= 5119.00
# |   |--- feature_3 <= 12.50
# |   |   |--- feature_0 <= 30.50
# |   |   |   |--- feature_0 <= 24.50
# |   |   |   |   |--- feature_5 <= 2468.00
# |   |   |   |   |   |--- feature_6 <= 44.50
# |   |   |   |   |   |   |--- feature_5 <= 1881.50
# |   |   |   |   |   |   |   |--- feature_4 <= 4243.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 21.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 546197.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 324421.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  324421.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  546197.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 554553.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  554553.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_0 >  21.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 83539.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 83344.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  83344.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  83539.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |--- feature_4 >  4243.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 4401.00
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_4 >  4401.00
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_5 >  1881.50
# |   |   |   |   |   |   |   |--- feature_1 <= 321773.00
# |   |   |   |   |   |   |   |   |--- feature_5 <= 1894.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_5 >  1894.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_1 >  321773.00
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |--- feature_6 >  44.50
# |   |   |   |   |   |   |--- feature_0 <= 23.50
# |   |   |   |   |   |   |   |--- feature_1 <= 323268.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 10.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 69.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  69.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 8.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  8.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_3 >  10.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 50452.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  50452.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 215808.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  215808.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- feature_1 >  323268.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 324263.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  324263.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 51.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 367725.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  367725.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  51.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_0 >  23.50
# |   |   |   |   |   |   |   |--- feature_6 <= 68.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 349708.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 198533.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 194788.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  194788.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  198533.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 46.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  46.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  349708.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 355606.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  355606.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- feature_6 >  68.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 103373.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  103373.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 251501.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  251501.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |--- feature_5 >  2468.00
# |   |   |   |   |   |--- class:  >50K
# |   |   |   |--- feature_0 >  24.50
# |   |   |   |   |--- feature_5 <= 1805.00
# |   |   |   |   |   |--- feature_6 <= 40.50
# |   |   |   |   |   |   |--- feature_3 <= 9.50
# |   |   |   |   |   |   |   |--- feature_0 <= 28.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 4164.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 29352.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 27562.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  27562.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  29352.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |--- feature_4 >  4164.00
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 4401.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  4401.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_0 >  28.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 11.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 9.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  9.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  11.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 47985.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  47985.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 7.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 29.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  29.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  7.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 39.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  39.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |--- feature_3 >  9.50
# |   |   |   |   |   |   |   |--- feature_0 <= 27.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 34.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_6 >  34.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 2966.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 302414.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 21
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  302414.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  2966.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 3214.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  3214.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_0 >  27.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 336037.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 29.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 184004.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  184004.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  29.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 234836.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  234836.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_1 >  336037.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 33.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  33.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |--- feature_6 >  40.50
# |   |   |   |   |   |   |--- feature_1 <= 102954.00
# |   |   |   |   |   |   |   |--- feature_6 <= 62.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 26.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 44.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  44.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 65895.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  65895.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_0 >  26.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 49.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  49.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 53.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  53.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_6 >  62.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 29.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 33835.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 67.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  67.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  33835.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_0 >  29.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 48922.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  48922.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |--- feature_1 >  102954.00
# |   |   |   |   |   |   |   |--- feature_1 <= 103514.00
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_1 >  103514.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 10.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 41.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  41.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 32
# |   |   |   |   |   |   |   |   |--- feature_3 >  10.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 195470.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 2728.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  2728.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  195470.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 226383.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  226383.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |--- feature_5 >  1805.00
# |   |   |   |   |   |--- feature_5 <= 1938.00
# |   |   |   |   |   |   |--- feature_1 <= 60283.00
# |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_1 >  60283.00
# |   |   |   |   |   |   |   |--- feature_3 <= 9.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 157824.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 111596.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  111596.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  157824.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 29.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  29.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_3 >  9.50
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |--- feature_5 >  1938.00
# |   |   |   |   |   |   |--- feature_5 <= 2205.00
# |   |   |   |   |   |   |   |--- feature_6 <= 17.50
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_6 >  17.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 11.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_3 >  11.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1978.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  1978.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_5 >  2205.00
# |   |   |   |   |   |   |   |--- feature_3 <= 9.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 223853.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  223853.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_3 >  9.50
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |--- feature_0 >  30.50
# |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |--- feature_5 <= 1805.00
# |   |   |   |   |   |--- feature_3 <= 9.50
# |   |   |   |   |   |   |--- feature_3 <= 8.50
# |   |   |   |   |   |   |   |--- feature_1 <= 103003.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 102965.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 99779.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 62.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  62.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  99779.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 35.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  35.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  102965.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_1 >  103003.00
# |   |   |   |   |   |   |   |   |--- feature_6 <= 29.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_6 >  29.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 32.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 431803.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  431803.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  32.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 183483.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  183483.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- feature_3 >  8.50
# |   |   |   |   |   |   |   |--- feature_1 <= 933517.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 59.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 52.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  52.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 90.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 28
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  90.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_0 >  59.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 87.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 63.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  63.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  87.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 167315.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  167315.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_1 >  933517.50
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |--- feature_3 >  9.50
# |   |   |   |   |   |   |--- feature_6 <= 44.50
# |   |   |   |   |   |   |   |--- feature_0 <= 64.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 182689.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 31767.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 31721.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  31721.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  31767.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 42660.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  42660.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |--- feature_1 >  182689.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 182905.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  182905.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 187128.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  187128.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 23
# |   |   |   |   |   |   |   |--- feature_0 >  64.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 112424.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 107724.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 38.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  38.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  107724.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  112424.00
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_6 >  44.50
# |   |   |   |   |   |   |   |--- feature_4 <= 4668.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 55.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 56.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  56.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 348164.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  348164.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_0 >  55.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 202928.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 173315.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  173315.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  202928.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_4 >  4668.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 47.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_6 >  47.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |--- feature_5 >  1805.00
# |   |   |   |   |   |--- feature_5 <= 1923.00
# |   |   |   |   |   |   |--- feature_0 <= 56.00
# |   |   |   |   |   |   |   |--- feature_0 <= 52.00
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_0 >  52.00
# |   |   |   |   |   |   |   |   |--- feature_6 <= 39.00
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_6 >  39.00
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |--- feature_0 >  56.00
# |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |--- feature_5 >  1923.00
# |   |   |   |   |   |   |--- feature_0 <= 60.50
# |   |   |   |   |   |   |   |--- feature_5 <= 2358.00
# |   |   |   |   |   |   |   |   |--- feature_5 <= 1978.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1975.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  1975.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_5 >  1978.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 59.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 2242.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  2242.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  59.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_5 >  2358.00
# |   |   |   |   |   |   |   |   |--- feature_5 <= 3158.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_5 >  3158.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_0 >  60.50
# |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |--- feature_5 <= 1820.50
# |   |   |   |   |   |--- feature_3 <= 8.50
# |   |   |   |   |   |   |--- feature_6 <= 40.50
# |   |   |   |   |   |   |   |--- feature_0 <= 37.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 180981.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 180217.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 118029.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  118029.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  180217.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 32.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  32.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  180981.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 378493.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 33.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  33.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  378493.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 381760.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  381760.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_0 >  37.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 3032.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 24.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  24.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 67.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 23
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  67.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_4 >  3032.00
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 3120.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  3120.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 35110.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  35110.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- feature_6 >  40.50
# |   |   |   |   |   |   |   |--- feature_3 <= 7.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 41.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 44.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 206600.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  206600.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  44.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 742.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  742.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_0 >  41.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 64.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 4083.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  4083.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  64.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_3 >  7.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 76156.00
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  76156.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 116419.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 49.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  49.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  116419.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 182431.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  182431.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |--- feature_3 >  8.50
# |   |   |   |   |   |   |--- feature_6 <= 35.50
# |   |   |   |   |   |   |   |--- feature_3 <= 9.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 29.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 204900.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  204900.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 210024.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  210024.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_6 >  29.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 40.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 410742.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  410742.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  40.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 64.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  64.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- feature_3 >  9.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 350511.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 35.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 290061.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  290061.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  35.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 34.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  34.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |--- feature_1 >  350511.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 360846.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  360846.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |--- feature_6 >  35.50
# |   |   |   |   |   |   |   |--- feature_0 <= 38.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 40.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 35.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 36
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  35.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 27
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 35.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 23
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  35.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |--- feature_6 >  40.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 120380.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 66.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 26
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  66.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  120380.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 28
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |--- feature_0 >  38.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 9.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 44.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 135260.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  135260.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 27
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  44.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 40.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 43
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  40.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 29
# |   |   |   |   |   |   |   |   |--- feature_3 >  9.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1571.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 200964.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 38
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  200964.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 39
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  1571.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |--- feature_5 >  1820.50
# |   |   |   |   |   |--- feature_5 <= 1978.50
# |   |   |   |   |   |   |--- feature_5 <= 1881.50
# |   |   |   |   |   |   |   |--- feature_5 <= 1862.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 66.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_0 >  66.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 80.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  80.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_5 >  1862.00
# |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_5 >  1881.50
# |   |   |   |   |   |   |   |--- feature_0 <= 64.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 1894.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_5 >  1894.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1975.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1938.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  1938.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  1975.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_0 >  64.50
# |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |--- feature_5 >  1978.50
# |   |   |   |   |   |   |--- feature_5 <= 2218.50
# |   |   |   |   |   |   |   |--- feature_0 <= 63.00
# |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_0 >  63.00
# |   |   |   |   |   |   |   |   |--- feature_5 <= 2161.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_5 >  2161.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 2190.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  2190.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_5 >  2218.50
# |   |   |   |   |   |   |   |--- feature_3 <= 9.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 2252.00
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_5 >  2252.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 2364.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 37.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  37.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  2364.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 44.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  44.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |--- feature_3 >  9.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 26155.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  26155.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 2450.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 2396.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  2396.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  2450.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 47.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  47.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |--- feature_3 >  12.50
# |   |   |--- feature_0 <= 29.50
# |   |   |   |--- feature_0 <= 27.50
# |   |   |   |   |--- feature_5 <= 1881.50
# |   |   |   |   |   |--- feature_6 <= 53.50
# |   |   |   |   |   |   |--- feature_0 <= 24.50
# |   |   |   |   |   |   |   |--- feature_1 <= 32111.00
# |   |   |   |   |   |   |   |   |--- feature_6 <= 22.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_6 >  22.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_1 >  32111.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 21.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 37.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  37.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 174377.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  174377.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_0 >  21.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 23.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  23.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 316849.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  316849.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- feature_0 >  24.50
# |   |   |   |   |   |   |   |--- feature_6 <= 37.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 782.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 33627.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 31204.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  31204.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  33627.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 26.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  26.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- feature_5 >  782.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1641.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  1641.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_6 >  37.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 329779.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 49.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  49.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 15.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  15.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_1 >  329779.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 330299.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  330299.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 41.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  41.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |--- feature_6 >  53.50
# |   |   |   |   |   |   |--- feature_1 <= 46720.00
# |   |   |   |   |   |   |   |--- feature_6 <= 57.50
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_6 >  57.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 25.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_0 >  25.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 38860.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  38860.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_1 >  46720.00
# |   |   |   |   |   |   |   |--- feature_5 <= 742.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 3808.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 24.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 209977.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  209977.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  24.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- feature_4 >  3808.00
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_5 >  742.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 1862.00
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_5 >  1862.00
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |--- feature_5 >  1881.50
# |   |   |   |   |   |--- feature_1 <= 122304.50
# |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |--- feature_1 >  122304.50
# |   |   |   |   |   |   |--- feature_1 <= 253004.50
# ...
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 203776.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 30.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  30.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  203776.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 259842.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  259842.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- feature_0 >  42.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 4102.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 520862.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  520862.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_4 >  4102.00
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |--- feature_3 >  14.50
# |   |   |   |   |   |   |   |--- feature_6 <= 23.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 69.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 11.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  11.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 31.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  31.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- feature_0 >  69.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 15.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  15.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 704.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  704.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_6 >  23.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 67.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 48.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  48.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 74312.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  74312.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- feature_0 >  67.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 24.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  24.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |--- feature_6 >  32.50
# |   |   |   |   |   |   |--- feature_3 <= 13.50
# |   |   |   |   |   |   |   |--- feature_6 <= 42.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 42.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 39.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 218874.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  218874.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  39.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 104968.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  104968.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 26
# |   |   |   |   |   |   |   |   |--- feature_0 >  42.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 68.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 54108.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  54108.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 38
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  68.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 37.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  37.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- feature_6 >  42.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 35.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 220672.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 102851.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  102851.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  220672.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 1087.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  1087.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_0 >  35.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 59.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 4973.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 26
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  4973.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  59.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 60.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  60.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_3 >  13.50
# |   |   |   |   |   |   |   |--- feature_4 <= 543.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 14.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 43.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 40.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  40.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 24
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  43.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 55.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  55.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 23
# |   |   |   |   |   |   |   |   |--- feature_3 >  14.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 31.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 145640.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  145640.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  31.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 72.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 21
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  72.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- feature_4 >  543.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 102727.00
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 2994.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  2994.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  102727.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 31.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  31.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 212607.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  212607.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |--- feature_5 >  1881.50
# |   |   |   |   |   |--- feature_5 <= 1978.50
# |   |   |   |   |   |   |--- feature_6 <= 31.00
# |   |   |   |   |   |   |   |--- feature_1 <= 102142.00
# |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_1 >  102142.00
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |--- feature_6 >  31.00
# |   |   |   |   |   |   |   |--- feature_1 <= 49159.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 48181.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  48181.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_1 >  49159.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 50.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_0 >  50.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 51.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1939.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  1939.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  51.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |--- feature_5 >  1978.50
# |   |   |   |   |   |   |--- feature_5 <= 2151.50
# |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_5 >  2151.50
# |   |   |   |   |   |   |   |--- feature_5 <= 2358.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 39.00
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_0 >  39.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 14.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 150411.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  150411.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  14.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 304202.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  304202.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_5 >  2358.00
# |   |   |   |   |   |   |   |   |--- feature_5 <= 3297.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 2384.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 54.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  54.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  2384.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 65.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  65.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_5 >  3297.00
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |--- feature_4 >  5119.00
# |   |--- feature_4 <= 7055.50
# |   |   |--- feature_4 <= 5316.50
# |   |   |   |--- class:  >50K
# |   |   |--- feature_4 >  5316.50
# |   |   |   |--- feature_0 <= 61.00
# |   |   |   |   |--- feature_0 <= 53.00
# |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |--- feature_0 >  53.00
# |   |   |   |   |   |--- feature_4 <= 6457.50
# |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |--- feature_4 >  6457.50
# |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |--- feature_0 >  61.00
# |   |   |   |   |--- feature_4 <= 6667.50
# |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |--- feature_3 <= 11.00
# |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |--- feature_3 >  11.00
# |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |--- feature_4 >  6667.50
# |   |   |   |   |   |--- class:  <=50K
# |   |--- feature_4 >  7055.50
# |   |   |--- feature_0 <= 20.50
# |   |   |   |--- feature_4 <= 24559.50
# |   |   |   |   |--- class:  >50K
# |   |   |   |--- feature_4 >  24559.50
# |   |   |   |   |--- class:  <=50K
# |   |   |--- feature_0 >  20.50
# |   |   |   |--- feature_3 <= 1.50
# |   |   |   |   |--- feature_1 <= 202918.00
# |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |--- feature_1 >  202918.00
# |   |   |   |   |   |--- class:  <=50K
# |   |   |   |--- feature_3 >  1.50
# |   |   |   |   |--- feature_1 <= 24872.50
# |   |   |   |   |   |--- feature_4 <= 7565.50
# |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |--- feature_4 >  7565.50
# |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |--- feature_1 >  24872.50
# |   |   |   |   |   |--- feature_0 <= 64.50
# |   |   |   |   |   |   |--- feature_6 <= 87.00
# |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 7565.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 7436.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  7436.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_4 >  7565.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |--- feature_6 >  87.00
# |   |   |   |   |   |   |   |--- feature_6 <= 93.00
# |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_6 >  93.00
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |--- feature_0 >  64.50
# |   |   |   |   |   |   |--- feature_4 <= 8682.00
# |   |   |   |   |   |   |   |--- feature_1 <= 162196.50
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_1 >  162196.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 213461.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  213461.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |--- feature_4 >  8682.00
# |   |   |   |   |   |   |   |--- feature_4 <= 10585.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 9976.00
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_4 >  9976.00
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_4 >  10585.50
# |   |   |   |   |   |   |   |   |--- class:  >50K

# %% [markdown]
# ### Does it help to normalize continuous values?

# %%
#Normalizing the data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
test_dec_tree=DecisionTreeClassifier().fit(X_train, y_train)

# %%
a = test_dec_tree.score(X_test, y_test)
print('Accuracy is: %', a*100)
# Out:
# Accuracy is: % 78.56850380804194

# %%
y_preds = test_dec_tree.predict(X_test)
print(classification_report(y_test, y_preds))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.86      0.85      0.86      9333
#         >50K       0.54      0.57      0.55      2878
#
#     accuracy                           0.79     12211
#    macro avg       0.70      0.71      0.71     12211
# weighted avg       0.79      0.79      0.79     12211

# %% [markdown]
# # We can do better... Try Deep Learning Model
#
# Requires "1-hot" class incoding

# %%
# output encodings
df["gt50k"] = df["class"].apply(lambda x: 1 if ">" in x else 0)
df["lte50k"] = df["class"].apply(lambda x: 1 if "<=" in x else 0)
df.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# 3      Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4      Married-civ-spouse      Prof-specialty            Wife   Black
# 5      Married-civ-spouse     Exec-managerial            Wife   White
# 6   Married-spouse-absent       Other-service   Not-in-family   Black
# 7      Married-civ-spouse     Exec-managerial         Husband   White
# 8           Never-married      Prof-specialty   Not-in-family   White
# 9      Married-civ-spouse     Exec-managerial         Husband   White
#
#        sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 0     Male          2174             0              40   United-States
# 1     Male             0             0              13   United-States
# 2     Male             0             0              40   United-States
# 3     Male             0             0              40   United-States
# 4   Female             0             0              40            Cuba
# 5   Female             0             0              40   United-States
# 6   Female             0             0              16         Jamaica
# 7     Male             0             0              45   United-States
# 8   Female         14084             0              50   United-States
# 9     Male          5178             0              40   United-States
#
#     class  sex-val  gt50k  lte50k
# 0   <=50K        1      0       1
# 1   <=50K        1      0       1
# 2   <=50K        1      0       1
# 3   <=50K        1      0       1
# 4   <=50K        0      0       1
# 5   <=50K        0      0       1
# 6   <=50K        0      0       1
# 7    >50K        1      1       0
# 8    >50K        0      1       0
# 9    >50K        1      1       0

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler

# %%
# Testing/Training Split
dy = df[["gt50k", "lte50k"]]
X_train, X_test, y_train, y_test = train_test_split(dft, dy)

# %%
#Normalizing the data
nnsc = StandardScaler()
X_train = nnsc.fit_transform(X_train)
X_test = nnsc.transform(X_test)

# %%
# Neural network
model = Sequential()
model.add(Dense(20, input_dim=7, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(2, activation='softmax'))
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                160
#
#  dense_1 (Dense)             (None, 16)                336
#
#  dense_2 (Dense)             (None, 2)                 34
#
# =================================================================
# Total params: 530
# Trainable params: 530
# Non-trainable params: 0
# _________________________________________________________________
# None
# 2022-06-08 12:39:54.082334: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train,validation_data = (X_test,y_test), epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.4337 - accuracy: 0.8036 - val_loss: 0.3707 - val_accuracy: 0.8338
# Epoch 2/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3776 - accuracy: 0.8269 - val_loss: 0.3669 - val_accuracy: 0.8377
# Epoch 3/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3746 - accuracy: 0.8286 - val_loss: 0.3660 - val_accuracy: 0.8352
# Epoch 4/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3733 - accuracy: 0.8291 - val_loss: 0.3659 - val_accuracy: 0.8338
# Epoch 5/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3720 - accuracy: 0.8294 - val_loss: 0.3639 - val_accuracy: 0.8366
# Epoch 6/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3713 - accuracy: 0.8297 - val_loss: 0.3663 - val_accuracy: 0.8338
# Epoch 7/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3707 - accuracy: 0.8299 - val_loss: 0.3635 - val_accuracy: 0.8364
# Epoch 8/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3700 - accuracy: 0.8306 - val_loss: 0.3632 - val_accuracy: 0.8373
# Epoch 9/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3692 - accuracy: 0.8307 - val_loss: 0.3650 - val_accuracy: 0.8354
# Epoch 10/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3691 - accuracy: 0.8305 - val_loss: 0.3628 - val_accuracy: 0.8352
# Epoch 11/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3686 - accuracy: 0.8309 - val_loss: 0.3622 - val_accuracy: 0.8360
# Epoch 12/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3678 - accuracy: 0.8316 - val_loss: 0.3625 - val_accuracy: 0.8366
# Epoch 13/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3679 - accuracy: 0.8310 - val_loss: 0.3627 - val_accuracy: 0.8365
# Epoch 14/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3675 - accuracy: 0.8314 - val_loss: 0.3619 - val_accuracy: 0.8357
# Epoch 15/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3674 - accuracy: 0.8313 - val_loss: 0.3612 - val_accuracy: 0.8369
# Epoch 16/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3669 - accuracy: 0.8321 - val_loss: 0.3618 - val_accuracy: 0.8362
# Epoch 17/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3666 - accuracy: 0.8307 - val_loss: 0.3618 - val_accuracy: 0.8356
# Epoch 18/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3662 - accuracy: 0.8323 - val_loss: 0.3624 - val_accuracy: 0.8360
# Epoch 19/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3660 - accuracy: 0.8322 - val_loss: 0.3613 - val_accuracy: 0.8360
# Epoch 20/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3658 - accuracy: 0.8322 - val_loss: 0.3616 - val_accuracy: 0.8359
# Epoch 21/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3656 - accuracy: 0.8326 - val_loss: 0.3607 - val_accuracy: 0.8362
# Epoch 22/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3652 - accuracy: 0.8323 - val_loss: 0.3606 - val_accuracy: 0.8351
# Epoch 23/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3650 - accuracy: 0.8316 - val_loss: 0.3602 - val_accuracy: 0.8359
# Epoch 24/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3651 - accuracy: 0.8332 - val_loss: 0.3607 - val_accuracy: 0.8365
# Epoch 25/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3645 - accuracy: 0.8328 - val_loss: 0.3607 - val_accuracy: 0.8352
# Epoch 26/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3644 - accuracy: 0.8325 - val_loss: 0.3606 - val_accuracy: 0.8362
# Epoch 27/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3641 - accuracy: 0.8328 - val_loss: 0.3602 - val_accuracy: 0.8357
# Epoch 28/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3641 - accuracy: 0.8328 - val_loss: 0.3614 - val_accuracy: 0.8356
# Epoch 29/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3635 - accuracy: 0.8322 - val_loss: 0.3598 - val_accuracy: 0.8352
# Epoch 30/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3636 - accuracy: 0.8330 - val_loss: 0.3598 - val_accuracy: 0.8351
# Epoch 31/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3636 - accuracy: 0.8330 - val_loss: 0.3597 - val_accuracy: 0.8350
# Epoch 32/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3630 - accuracy: 0.8330 - val_loss: 0.3608 - val_accuracy: 0.8348
# Epoch 33/100
# 573/573 [==============================] - 2s 3ms/step - loss: 0.3631 - accuracy: 0.8328 - val_loss: 0.3590 - val_accuracy: 0.8355
# Epoch 34/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3629 - accuracy: 0.8332 - val_loss: 0.3596 - val_accuracy: 0.8360
# Epoch 35/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3623 - accuracy: 0.8328 - val_loss: 0.3624 - val_accuracy: 0.8344
# Epoch 36/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3625 - accuracy: 0.8337 - val_loss: 0.3595 - val_accuracy: 0.8345
# Epoch 37/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3619 - accuracy: 0.8335 - val_loss: 0.3600 - val_accuracy: 0.8334
# Epoch 38/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3619 - accuracy: 0.8333 - val_loss: 0.3590 - val_accuracy: 0.8351
# Epoch 39/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3618 - accuracy: 0.8330 - val_loss: 0.3589 - val_accuracy: 0.8367
# Epoch 40/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3616 - accuracy: 0.8333 - val_loss: 0.3589 - val_accuracy: 0.8356
# Epoch 41/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3614 - accuracy: 0.8332 - val_loss: 0.3599 - val_accuracy: 0.8345
# Epoch 42/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3615 - accuracy: 0.8337 - val_loss: 0.3584 - val_accuracy: 0.8357
# Epoch 43/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3609 - accuracy: 0.8334 - val_loss: 0.3578 - val_accuracy: 0.8366
# Epoch 44/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3609 - accuracy: 0.8338 - val_loss: 0.3601 - val_accuracy: 0.8343
# Epoch 45/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3608 - accuracy: 0.8335 - val_loss: 0.3592 - val_accuracy: 0.8363
# Epoch 46/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3606 - accuracy: 0.8335 - val_loss: 0.3592 - val_accuracy: 0.8349
# Epoch 47/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3606 - accuracy: 0.8337 - val_loss: 0.3589 - val_accuracy: 0.8374
# Epoch 48/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3606 - accuracy: 0.8335 - val_loss: 0.3602 - val_accuracy: 0.8363
# Epoch 49/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3606 - accuracy: 0.8328 - val_loss: 0.3583 - val_accuracy: 0.8376
# Epoch 50/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3602 - accuracy: 0.8336 - val_loss: 0.3590 - val_accuracy: 0.8360
# Epoch 51/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3602 - accuracy: 0.8339 - val_loss: 0.3584 - val_accuracy: 0.8370
# Epoch 52/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3604 - accuracy: 0.8337 - val_loss: 0.3586 - val_accuracy: 0.8365
# Epoch 53/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3601 - accuracy: 0.8343 - val_loss: 0.3605 - val_accuracy: 0.8362
# Epoch 54/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3605 - accuracy: 0.8342 - val_loss: 0.3583 - val_accuracy: 0.8364
# Epoch 55/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3599 - accuracy: 0.8342 - val_loss: 0.3596 - val_accuracy: 0.8351
# Epoch 56/100
# 573/573 [==============================] - 2s 3ms/step - loss: 0.3599 - accuracy: 0.8342 - val_loss: 0.3594 - val_accuracy: 0.8367
# Epoch 57/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3599 - accuracy: 0.8336 - val_loss: 0.3590 - val_accuracy: 0.8378
# Epoch 58/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3597 - accuracy: 0.8345 - val_loss: 0.3582 - val_accuracy: 0.8365
# Epoch 59/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3597 - accuracy: 0.8342 - val_loss: 0.3587 - val_accuracy: 0.8354
# Epoch 60/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3597 - accuracy: 0.8348 - val_loss: 0.3595 - val_accuracy: 0.8361
# Epoch 61/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3597 - accuracy: 0.8346 - val_loss: 0.3619 - val_accuracy: 0.8362
# Epoch 62/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3596 - accuracy: 0.8346 - val_loss: 0.3590 - val_accuracy: 0.8358
# Epoch 63/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3593 - accuracy: 0.8348 - val_loss: 0.3581 - val_accuracy: 0.8375
# Epoch 64/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3594 - accuracy: 0.8353 - val_loss: 0.3582 - val_accuracy: 0.8371
# Epoch 65/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3597 - accuracy: 0.8346 - val_loss: 0.3580 - val_accuracy: 0.8368
# Epoch 66/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3592 - accuracy: 0.8349 - val_loss: 0.3605 - val_accuracy: 0.8369
# Epoch 67/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3596 - accuracy: 0.8351 - val_loss: 0.3586 - val_accuracy: 0.8388
# Epoch 68/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3595 - accuracy: 0.8335 - val_loss: 0.3583 - val_accuracy: 0.8370
# Epoch 69/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3596 - accuracy: 0.8348 - val_loss: 0.3586 - val_accuracy: 0.8369
# Epoch 70/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3590 - accuracy: 0.8350 - val_loss: 0.3579 - val_accuracy: 0.8373
# Epoch 71/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3591 - accuracy: 0.8346 - val_loss: 0.3600 - val_accuracy: 0.8349
# Epoch 72/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3594 - accuracy: 0.8352 - val_loss: 0.3600 - val_accuracy: 0.8377
# Epoch 73/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3592 - accuracy: 0.8344 - val_loss: 0.3593 - val_accuracy: 0.8386
# Epoch 74/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3593 - accuracy: 0.8353 - val_loss: 0.3582 - val_accuracy: 0.8361
# Epoch 75/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3591 - accuracy: 0.8343 - val_loss: 0.3585 - val_accuracy: 0.8373
# Epoch 76/100
# 573/573 [==============================] - 1s 3ms/step - loss: 0.3593 - accuracy: 0.8354 - val_loss: 0.3597 - val_accuracy: 0.8389
# Epoch 77/100
# 573/573 [==============================] - 2s 3ms/step - loss: 0.3591 - accuracy: 0.8356 - val_loss: 0.3581 - val_accuracy: 0.8374
# Epoch 78/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3589 - accuracy: 0.8353 - val_loss: 0.3591 - val_accuracy: 0.8367
# Epoch 79/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3590 - accuracy: 0.8355 - val_loss: 0.3587 - val_accuracy: 0.8360
# Epoch 80/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3589 - accuracy: 0.8347 - val_loss: 0.3583 - val_accuracy: 0.8356
# Epoch 81/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3587 - accuracy: 0.8354 - val_loss: 0.3587 - val_accuracy: 0.8364
# Epoch 82/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3589 - accuracy: 0.8352 - val_loss: 0.3586 - val_accuracy: 0.8365
# Epoch 83/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3587 - accuracy: 0.8344 - val_loss: 0.3581 - val_accuracy: 0.8372
# Epoch 84/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3586 - accuracy: 0.8360 - val_loss: 0.3588 - val_accuracy: 0.8361
# Epoch 85/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3590 - accuracy: 0.8348 - val_loss: 0.3598 - val_accuracy: 0.8385
# Epoch 86/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3585 - accuracy: 0.8352 - val_loss: 0.3581 - val_accuracy: 0.8362
# Epoch 87/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3585 - accuracy: 0.8349 - val_loss: 0.3581 - val_accuracy: 0.8364
# Epoch 88/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3584 - accuracy: 0.8352 - val_loss: 0.3596 - val_accuracy: 0.8377
# Epoch 89/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3587 - accuracy: 0.8352 - val_loss: 0.3600 - val_accuracy: 0.8382
# Epoch 90/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3586 - accuracy: 0.8353 - val_loss: 0.3579 - val_accuracy: 0.8369
# Epoch 91/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3584 - accuracy: 0.8352 - val_loss: 0.3582 - val_accuracy: 0.8352
# Epoch 92/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3586 - accuracy: 0.8351 - val_loss: 0.3607 - val_accuracy: 0.8368
# Epoch 93/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3584 - accuracy: 0.8351 - val_loss: 0.3601 - val_accuracy: 0.8369
# Epoch 94/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3584 - accuracy: 0.8349 - val_loss: 0.3579 - val_accuracy: 0.8364
# Epoch 95/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3586 - accuracy: 0.8355 - val_loss: 0.3579 - val_accuracy: 0.8356
# Epoch 96/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3586 - accuracy: 0.8352 - val_loss: 0.3596 - val_accuracy: 0.8381
# Epoch 97/100
# 573/573 [==============================] - 1s 3ms/step - loss: 0.3584 - accuracy: 0.8357 - val_loss: 0.3587 - val_accuracy: 0.8356
# Epoch 98/100
# 573/573 [==============================] - 2s 3ms/step - loss: 0.3583 - accuracy: 0.8352 - val_loss: 0.3593 - val_accuracy: 0.8366
# Epoch 99/100
# 573/573 [==============================] - 2s 3ms/step - loss: 0.3583 - accuracy: 0.8344 - val_loss: 0.3580 - val_accuracy: 0.8359
# Epoch 100/100
# 573/573 [==============================] - 2s 3ms/step - loss: 0.3586 - accuracy: 0.8355 - val_loss: 0.3576 - val_accuracy: 0.8367

# %%
y_pred = model.predict(X_test)
# Out:
# 382/382 [==============================] - 0s 838us/step

# %%
#Converting 1-hot predictions to class label
pred = list()
for i in range(len(y_pred)):
    pred.append(np.argmax(y_pred[i]))

# %%
# Because 1-hot is (0,1), this is also class label index
test = list(y_test.lte50k)

# %%
from sklearn.metrics import accuracy_score
a = accuracy_score(pred,test)
print('Accuracy is: %', a*100)
# Out:
# Accuracy is: % 83.67046105970027

# %%
print(classification_report(test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.49      0.59      2913
#            1       0.85      0.95      0.90      9298
#
#     accuracy                           0.84     12211
#    macro avg       0.80      0.72      0.74     12211
# weighted avg       0.83      0.84      0.82     12211

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss']) 
plt.plot(history.history['val_loss']) 
plt.title('Model loss') 
plt.ylabel('Loss') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper left') 
plt.show()

# %% [markdown]
# # Next time... Deploying a model
#
# Save trained models for use in prediction algorithms

# %%
from joblib import dump, load
dump(dec_tree, "decision_tree.pkl")
dump(model, "neural_net.pkl")
dump(nnsc, "neural_net_scaler.pkl")

# %% [markdown]
# # Input Data Vetting

# %%
vdata = [["Feature", "count", "mean", "std", "min", "25%", "50%", "75%", "max"]]
for h in features:
    row = []
    row.append(h)
    print("#"*25)
    x = df[h].describe()
    print(x)
    row.extend(list(x))
    vdata.append(row)

# %%
import csv
with open("../data/feature_vetting.csv", "w") as outfile:
    wrtr = csv.writer(outfile)
    wrtr.writerows(vdata)

# %% [markdown]
# # Simple Model Build Example
# ### Part II -- Next up Simple Model Deploy on K8s
# 2022 June 1
#
# ### The Job is to predict level adult earnings per year
#
# Data we have available has incomes above or below $50K based on deomographics
#
# ![alt text](../img/model_grid.png "Model Grid")

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

from model.training_data import *

# %matplotlib inline

# %% [markdown]
# ## Training Data

# %%
print(file_path)
# !ls $file_path
# Out:
# ../data/
# adult.data            decision_tree.pkl     neural_net.pkl
# adult.names           feature_vetting.csv   neural_net_scaler.pkl

# %%
header = get_header()
print("\n".join(header))
# Out:
# age
# workclass
# fnlwgt
# education
# education-num
# marital-status
# occupation
# relationship
# race
# sex
# capital-gain
# capital-loss
# hours-per-week
# native-country
# class

# %%
df = get_training_dataframe()
df.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# 3      Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4      Married-civ-spouse      Prof-specialty            Wife   Black
# 5      Married-civ-spouse     Exec-managerial            Wife   White
# 6   Married-spouse-absent       Other-service   Not-in-family   Black
# 7      Married-civ-spouse     Exec-managerial         Husband   White
# 8           Never-married      Prof-specialty   Not-in-family   White
# 9      Married-civ-spouse     Exec-managerial         Husband   White
#
#        sex  capital-gain  capital-loss  hours-per-week  native-country   class
# 0     Male          2174             0              40   United-States   <=50K
# 1     Male             0             0              13   United-States   <=50K
# 2     Male             0             0              40   United-States   <=50K
# 3     Male             0             0              40   United-States   <=50K
# 4   Female             0             0              40            Cuba   <=50K
# 5   Female             0             0              40   United-States   <=50K
# 6   Female             0             0              16         Jamaica   <=50K
# 7     Male             0             0              45   United-States    >50K
# 8   Female         14084             0              50   United-States    >50K
# 9     Male          5178             0              40   United-States    >50K

# %% [markdown]
# ### Explore the Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       48842 non-null  object
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  object
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  object
#  6   occupation      48842 non-null  object
#  7   relationship    48842 non-null  object
#  8   race            48842 non-null  object
#  9   sex             48842 non-null  object
#  10  capital-gain    48842 non-null  int64
#  11  capital-loss    48842 non-null  int64
#  12  hours-per-week  48842 non-null  int64
#  13  native-country  48842 non-null  object
#  14  class           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  48842.000000  4.884200e+04   48842.000000  48842.000000  48842.000000
# mean      38.643585  1.896641e+05      10.078089   1079.067626     87.502314
# std       13.710510  1.056040e+05       2.570973   7452.019058    403.004552
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.175505e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.781445e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.376420e+05      12.000000      0.000000      0.000000
# max       90.000000  1.490400e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    48842.000000
# mean        40.422382
# std         12.391444
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
for h in header:
    n = len(df[h].value_counts())
    if n < 20:
        print("#"*25)
        print(f"{h}: {n}")
        print(df[h].value_counts())
        print("-"*20)
        print(df[h].describe())
# Out:
# #########################
# workclass: 9
#  Private             33906
#  Self-emp-not-inc     3862
#  Local-gov            3136
#  ?                    2799
#  State-gov            1981
#  Self-emp-inc         1695
#  Federal-gov          1432
#  Without-pay            21
#  Never-worked           10
# Name: workclass, dtype: int64
# --------------------
# count        48842
# unique           9
# top        Private
# freq         33906
# Name: workclass, dtype: object
# #########################
# education: 16
#  HS-grad         15784
#  Some-college    10878
#  Bachelors        8025
#  Masters          2657
#  Assoc-voc        2061
#  11th             1812
#  Assoc-acdm       1601
#  10th             1389
#  7th-8th           955
#  Prof-school       834
#  9th               756
#  12th              657
#  Doctorate         594
#  5th-6th           509
#  1st-4th           247
#  Preschool          83
# Name: education, dtype: int64
# --------------------
# count        48842
# unique          16
# top        HS-grad
# freq         15784
# Name: education, dtype: object
# #########################
# education-num: 16
# 9     15784
# 10    10878
# 13     8025
# 14     2657
# 11     2061
# 7      1812
# 12     1601
# 6      1389
# 4       955
# 15      834
# 5       756
# 8       657
# 16      594
# 3       509
# 2       247
# 1        83
# Name: education-num, dtype: int64
# --------------------
# count    48842.000000
# mean        10.078089
# std          2.570973
# min          1.000000
# 25%          9.000000
# 50%         10.000000
# 75%         12.000000
# max         16.000000
# Name: education-num, dtype: float64
# #########################
# marital-status: 7
#  Married-civ-spouse       22379
#  Never-married            16117
#  Divorced                  6633
#  Separated                 1530
#  Widowed                   1518
#  Married-spouse-absent      628
#  Married-AF-spouse           37
# Name: marital-status, dtype: int64
# --------------------
# count                   48842
# unique                      7
# top        Married-civ-spouse
# freq                    22379
# Name: marital-status, dtype: object
# #########################
# occupation: 15
#  Prof-specialty       6172
#  Craft-repair         6112
#  Exec-managerial      6086
#  Adm-clerical         5611
#  Sales                5504
#  Other-service        4923
#  Machine-op-inspct    3022
#  ?                    2809
#  Transport-moving     2355
#  Handlers-cleaners    2072
#  Farming-fishing      1490
#  Tech-support         1446
#  Protective-serv       983
#  Priv-house-serv       242
#  Armed-Forces           15
# Name: occupation, dtype: int64
# --------------------
# count               48842
# unique                 15
# top        Prof-specialty
# freq                 6172
# Name: occupation, dtype: object
# #########################
# relationship: 6
#  Husband           19716
#  Not-in-family     12583
#  Own-child          7581
#  Unmarried          5125
#  Wife               2331
#  Other-relative     1506
# Name: relationship, dtype: int64
# --------------------
# count        48842
# unique           6
# top        Husband
# freq         19716
# Name: relationship, dtype: object
# #########################
# race: 5
#  White                 41762
#  Black                  4685
#  Asian-Pac-Islander     1519
#  Amer-Indian-Eskimo      470
#  Other                   406
# Name: race, dtype: int64
# --------------------
# count      48842
# unique         5
# top        White
# freq       41762
# Name: race, dtype: object
# #########################
# sex: 2
#  Male      32650
#  Female    16192
# Name: sex, dtype: int64
# --------------------
# count     48842
# unique        2
# top        Male
# freq      32650
# Name: sex, dtype: object
# #########################
# class: 2
#  <=50K    37155
#  >50K     11687
# Name: class, dtype: int64
# --------------------
# count      48842
# unique         2
# top        <=50K
# freq       37155
# Name: class, dtype: object

# %% [markdown]
# ### Encoding classes will help a classifiers include all the inforamtion available
# Start with an easy one...Sex in this data set has only 2 values.

# %%
# input encodings
df["sex-val"] = df["sex"].apply(lambda x: 1 if "M" in x else 0)
df[["sex", "sex-val"]].head(10)
# Out:
#        sex  sex-val
# 0     Male        1
# 1     Male        1
# 2     Male        1
# 3     Male        1
# 4   Female        0
# 5   Female        0
# 6   Female        0
# 7     Male        1
# 8   Female        0
# 9     Male        1

# %% [markdown]
# ### Start modeling with a simple case -- only encoded or continuous data

# %%
print(features)
dft = df[features].copy()
y = df["class"]
# Out:
# ['age', 'fnlwgt', 'sex-val', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn import tree

# %% [markdown]
# ### Testing and Training sets help us evaluate performance
#
# ![alt text](../img/test_train_split.png "Test Train Split")

# %%
X_train, X_test, y_train, y_test = train_test_split(dft, y)

# %%
dec_tree=DecisionTreeClassifier().fit(X_train, y_train)
a = dec_tree.score(X_test, y_test)
print('Accuracy is: %', a*100)
# Out:
# Accuracy is: % 78.47842109573335

# %%
y_preds = dec_tree.predict(X_test)
print(classification_report(y_test, y_preds))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.86      0.86      0.86      9256
#         >50K       0.55      0.56      0.56      2955
#
#     accuracy                           0.78     12211
#    macro avg       0.71      0.71      0.71     12211
# weighted avg       0.79      0.78      0.79     12211

# %% [markdown]
# ### Let's look at the decision tree...
#
# High dimensionality, so maybe too complex to be explanatory? Also, maybe generate some skepticism on how will it will generalize?

# %%
text_representation = tree.export_text(dec_tree)
print(text_representation)
# Out:
# |--- feature_4 <= 5119.00
# |   |--- feature_3 <= 12.50
# |   |   |--- feature_0 <= 29.50
# |   |   |   |--- feature_0 <= 24.50
# |   |   |   |   |--- feature_5 <= 2468.00
# |   |   |   |   |   |--- feature_5 <= 1881.50
# |   |   |   |   |   |   |--- feature_0 <= 23.50
# |   |   |   |   |   |   |   |--- feature_0 <= 21.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 546197.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 11.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 324751.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  324751.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  11.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 43.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  43.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_1 >  546197.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 550328.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  550328.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_0 >  21.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 47.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 172773.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  172773.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |--- feature_6 >  47.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 43257.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 40871.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  40871.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  43257.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 367725.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  367725.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- feature_0 >  23.50
# |   |   |   |   |   |   |   |--- feature_6 <= 67.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 2994.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 44.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 23840.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  23840.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  44.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 161608.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  161608.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |--- feature_4 >  2994.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 179689.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 113886.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  113886.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  179689.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_6 >  67.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 73.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_6 >  73.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |--- feature_5 >  1881.50
# |   |   |   |   |   |   |--- feature_5 <= 1938.00
# |   |   |   |   |   |   |   |--- feature_1 <= 234090.50
# |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_1 >  234090.50
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |--- feature_5 >  1938.00
# |   |   |   |   |   |   |   |--- feature_5 <= 1978.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 1975.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_5 >  1975.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_5 >  1978.50
# |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |--- feature_5 >  2468.00
# |   |   |   |   |   |--- feature_0 <= 21.50
# |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |--- feature_0 >  21.50
# |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |--- feature_0 >  24.50
# |   |   |   |   |--- feature_5 <= 1805.00
# |   |   |   |   |   |--- feature_6 <= 40.50
# |   |   |   |   |   |   |--- feature_3 <= 9.50
# |   |   |   |   |   |   |   |--- feature_0 <= 28.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 29352.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 27562.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 39.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  39.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  27562.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  29352.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 3005.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 190205.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  190205.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  3005.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 3120.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  3120.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- feature_0 >  28.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 4083.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 11.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  11.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |--- feature_4 >  4083.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |--- feature_3 >  9.50
# |   |   |   |   |   |   |   |--- feature_0 <= 26.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 782.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 27575.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 26319.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  26319.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  27575.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 33.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  33.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |--- feature_5 >  782.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_0 >  26.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 296767.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 35.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 56274.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  56274.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  35.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 128264.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  128264.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |--- feature_1 >  296767.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |--- feature_6 >  40.50
# |   |   |   |   |   |   |--- feature_3 <= 10.50
# |   |   |   |   |   |   |   |--- feature_1 <= 388984.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 4243.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 41.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 27.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  27.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  41.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |--- feature_4 >  4243.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 27.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  27.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_1 >  388984.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 398268.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 7.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  7.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 47.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  47.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_1 >  398268.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 28.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 64.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  64.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  28.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 46.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  46.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_3 >  10.50
# |   |   |   |   |   |   |   |--- feature_1 <= 199322.00
# |   |   |   |   |   |   |   |   |--- feature_4 <= 2728.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 27004.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  27004.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 42.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  42.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- feature_4 >  2728.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_1 >  199322.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 226383.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 55.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 204839.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  204839.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  55.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  226383.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1094.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 28.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  28.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  1094.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |--- feature_5 >  1805.00
# |   |   |   |   |   |--- feature_5 <= 1938.00
# |   |   |   |   |   |   |--- feature_1 <= 157824.50
# |   |   |   |   |   |   |   |--- feature_3 <= 9.50
# |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_3 >  9.50
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |--- feature_1 >  157824.50
# |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |--- feature_5 >  1938.00
# |   |   |   |   |   |   |--- feature_5 <= 2396.00
# |   |   |   |   |   |   |   |--- feature_1 <= 248738.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 101744.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 26.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  26.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  101744.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_1 >  248738.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 282844.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  282844.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_5 >  2396.00
# |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |--- feature_0 >  29.50
# |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |--- feature_5 <= 1881.50
# |   |   |   |   |   |--- feature_3 <= 9.50
# |   |   |   |   |   |   |--- feature_3 <= 7.50
# |   |   |   |   |   |   |   |--- feature_1 <= 103003.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 102965.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 99779.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  99779.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 36.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  36.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  102965.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_1 >  103003.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 39.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_0 >  39.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 431199.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  431199.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 439962.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  439962.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_3 >  7.50
# |   |   |   |   |   |   |   |--- feature_4 <= 4243.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 89803.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 28155.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 28003.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  28003.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  28155.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 31033.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  31033.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |--- feature_1 >  89803.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 90098.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  90098.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 97.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 34
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  97.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- feature_4 >  4243.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 4826.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 52.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  52.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_4 >  4826.00
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |--- feature_3 >  9.50
# |   |   |   |   |   |   |--- feature_6 <= 44.50
# |   |   |   |   |   |   |   |--- feature_0 <= 61.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 182733.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 22.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 109866.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  109866.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  22.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 24000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  24000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 24
# |   |   |   |   |   |   |   |   |--- feature_1 >  182733.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1446.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 182905.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  182905.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  1446.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1494.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  1494.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- feature_0 >  61.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 264945.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 163166.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 159549.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  159549.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  163166.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  264945.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 267930.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  267930.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 32.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  32.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- feature_6 >  44.50
# |   |   |   |   |   |   |   |--- feature_4 <= 4668.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 32.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 245451.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  245451.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 259202.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  259202.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_0 >  32.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 56.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 61.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  61.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  56.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 20002.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  20002.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |--- feature_4 >  4668.50
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |--- feature_5 >  1881.50
# |   |   |   |   |   |--- feature_5 <= 1923.00
# |   |   |   |   |   |   |--- feature_3 <= 10.50
# |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |--- feature_3 >  10.50
# |   |   |   |   |   |   |   |--- feature_1 <= 100551.50
# |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_1 >  100551.50
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |--- feature_5 >  1923.00
# |   |   |   |   |   |   |--- feature_0 <= 50.50
# |   |   |   |   |   |   |   |--- feature_6 <= 35.50
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_6 >  35.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 2248.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 48.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 11.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  11.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  48.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_5 >  2248.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 3107.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  3107.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_0 >  50.50
# |   |   |   |   |   |   |   |--- feature_1 <= 59889.00
# |   |   |   |   |   |   |   |   |--- feature_6 <= 45.00
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_6 >  45.00
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_1 >  59889.00
# |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |--- feature_5 <= 1846.00
# |   |   |   |   |   |--- feature_3 <= 8.50
# |   |   |   |   |   |   |--- feature_6 <= 40.50
# |   |   |   |   |   |   |   |--- feature_4 <= 4243.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 37.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 118029.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 117343.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  117343.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  118029.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 33.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  33.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_0 >  37.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 34.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 26556.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  26556.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  34.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |--- feature_4 >  4243.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 4699.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_4 >  4699.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_6 >  40.50
# |   |   |   |   |   |   |   |--- feature_0 <= 46.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 114835.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 7.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 97.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  97.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  7.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 107499.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  107499.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  114835.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 386633.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 2755.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  2755.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  386633.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 30.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  30.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |--- feature_0 >  46.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 109802.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 104867.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 104495.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  104495.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  104867.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  109802.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 119277.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 55.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  55.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  119277.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |--- feature_3 >  8.50
# |   |   |   |   |   |   |--- feature_6 <= 35.50
# |   |   |   |   |   |   |   |--- feature_3 <= 9.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 34.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 231711.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 229759.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  229759.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  231711.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_6 >  34.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 30230.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  30230.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 41.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  41.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |--- feature_3 >  9.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 69.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 182579.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 49.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  49.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  182579.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 13.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  13.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |--- feature_0 >  69.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 175601.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 144017.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  144017.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  175601.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 438027.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  438027.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- feature_6 >  35.50
# |   |   |   |   |   |   |   |--- feature_0 <= 36.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 41.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 104648.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  104648.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 23
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 33.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  33.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 29
# |   |   |   |   |   |   |   |   |--- feature_6 >  41.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 121258.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  121258.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 27
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 83333.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  83333.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 21
# |   |   |   |   |   |   |   |--- feature_0 >  36.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 9.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 44.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 121993.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 21
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  121993.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 30
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  44.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 40.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 36
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  40.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 43
# |   |   |   |   |   |   |   |   |--- feature_3 >  9.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 117094.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 64.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 24
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  64.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  117094.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 42.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 29
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  42.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 31
# |   |   |   |   |--- feature_5 >  1846.00
# |   |   |   |   |   |--- feature_5 <= 1978.50
# |   |   |   |   |   |   |--- feature_5 <= 1881.50
# |   |   |   |   |   |   |   |--- feature_5 <= 1862.00
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_5 >  1862.00
# |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_5 >  1881.50
# |   |   |   |   |   |   |   |--- feature_0 <= 64.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 4.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 49.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  49.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_3 >  4.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1894.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  1894.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 37.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  37.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |--- feature_0 >  64.00
# |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |--- feature_5 >  1978.50
# |   |   |   |   |   |   |--- feature_5 <= 2161.50
# |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_5 >  2161.50
# |   |   |   |   |   |   |   |--- feature_5 <= 2384.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 64.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 106610.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 56.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  56.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  106610.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 158579.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  158579.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_0 >  64.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 134381.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 2190.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  2190.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  134381.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_5 >  2384.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 41.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 2450.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  2450.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 42063.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  42063.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_6 >  41.00
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |--- feature_3 >  12.50
# |   |   |--- feature_0 <= 29.50
# |   |   |   |--- feature_0 <= 27.50
# |   |   |   |   |--- feature_5 <= 1881.50
# |   |   |   |   |   |--- feature_0 <= 24.50
# |   |   |   |   |   |   |--- feature_4 <= 4601.50
# |   |   |   |   |   |   |   |--- feature_1 <= 32111.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 31496.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  31496.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_1 >  32111.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 23.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 21.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 39.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  39.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  21.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_0 >  23.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 58428.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 57265.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  57265.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  58428.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 312666.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  312666.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- feature_4 >  4601.50
# |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |--- feature_0 >  24.50
# |   |   |   |   |   |   |--- feature_6 <= 85.00
# |   |   |   |   |   |   |   |--- feature_6 <= 44.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 23912.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  23912.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 37.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 782.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  782.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  37.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 14.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  14.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- feature_6 >  44.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 1787.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 46.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 173515.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  173515.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  46.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 190979.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  190979.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- feature_5 >  1787.00
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |--- feature_6 >  85.00
# |   |   |   |   |   |   |   |--- feature_6 <= 94.50
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_6 >  94.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 26.00
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_0 >  26.00
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |--- feature_5 >  1881.50
# |   |   |   |   |   |--- feature_5 <= 1989.00
# |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |--- feature_5 >  1989.00
# |   |   |   |   |   |   |--- feature_5 <= 2218.00
# |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_5 >  2218.00
# |   |   |   |   |   |   |   |--- feature_5 <= 2298.50
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_5 >  2298.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 2391.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_5 >  2391.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |--- feature_0 >  27.50
# |   |   |   |   |--- feature_6 <= 41.00
# |   |   |   |   |   |--- feature_5 <= 1446.50
# |   |   |   |   |   |   |--- feature_4 <= 2652.50
# |   |   |   |   |   |   |   |--- feature_0 <= 28.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 31635.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  31635.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 27.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  27.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 191549.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  191549.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |--- feature_0 >  28.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 214773.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 179078.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 176712.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  176712.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  179078.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  214773.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 224273.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  224273.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 15.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  15.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |--- feature_4 >  2652.50
# |   |   |   |   |   |   |   |--- feature_4 <= 3876.50
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_4 >  3876.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 138436.00
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  138436.00
# ...
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  169542.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 36.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  36.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- feature_0 >  40.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 67.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 51.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 420579.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  420579.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  51.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 182601.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  182601.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- feature_0 >  67.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 33443.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 74.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  74.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  33443.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1667.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  1667.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |--- feature_3 >  14.50
# |   |   |   |   |   |   |   |--- feature_6 <= 22.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 117051.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 704.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 45.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  45.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  704.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  117051.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 57.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 32.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  32.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  57.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 184867.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  184867.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- feature_6 >  22.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 61061.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  61061.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 58.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  58.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 60.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  60.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |--- feature_6 >  30.50
# |   |   |   |   |   |   |--- feature_3 <= 13.50
# |   |   |   |   |   |   |   |--- feature_0 <= 39.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 40.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 39.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 228404.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  228404.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  39.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 92247.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  92247.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 21
# |   |   |   |   |   |   |   |   |--- feature_6 >  40.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 33.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 72758.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  72758.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  33.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 165359.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  165359.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |--- feature_0 >  39.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 3120.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 895.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 2994.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 29
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  2994.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  895.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1832.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  1832.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_4 >  3120.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 47.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 4718.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  4718.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  47.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 195652.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  195652.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_3 >  13.50
# |   |   |   |   |   |   |   |--- feature_0 <= 70.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 14.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 45.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 154392.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  154392.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  45.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 58.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  58.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |--- feature_3 >  14.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 543.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 31.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  31.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 24
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  543.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 4225.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  4225.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- feature_0 >  70.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 172327.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 140675.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 14.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  14.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  140675.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  172327.50
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |--- feature_5 >  1881.50
# |   |   |   |   |   |--- feature_5 <= 1978.50
# |   |   |   |   |   |   |--- feature_6 <= 31.00
# |   |   |   |   |   |   |   |--- feature_1 <= 102142.00
# |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_1 >  102142.00
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |--- feature_6 >  31.00
# |   |   |   |   |   |   |   |--- feature_1 <= 33199.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 32922.00
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_1 >  32922.00
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_1 >  33199.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 50.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_0 >  50.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 51.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 45.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  45.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  51.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |--- feature_5 >  1978.50
# |   |   |   |   |   |   |--- feature_5 <= 2358.00
# |   |   |   |   |   |   |   |--- feature_0 <= 65.00
# |   |   |   |   |   |   |   |   |--- feature_5 <= 2205.00
# |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_5 >  2205.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 2252.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  2252.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 40.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  40.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- feature_0 >  65.00
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |--- feature_5 >  2358.00
# |   |   |   |   |   |   |   |--- feature_5 <= 3387.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 66.00
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |--- feature_0 >  66.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 2424.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  2424.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_5 >  3387.00
# |   |   |   |   |   |   |   |   |--- class:  <=50K
# |--- feature_4 >  5119.00
# |   |--- feature_4 <= 7055.50
# |   |   |--- feature_4 <= 5316.50
# |   |   |   |--- class:  >50K
# |   |   |--- feature_4 >  5316.50
# |   |   |   |--- feature_0 <= 61.00
# |   |   |   |   |--- feature_0 <= 54.50
# |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |--- feature_0 >  54.50
# |   |   |   |   |   |--- feature_4 <= 6457.50
# |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |--- feature_4 >  6457.50
# |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |--- feature_0 >  61.00
# |   |   |   |   |--- feature_4 <= 6618.50
# |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |--- feature_4 >  6618.50
# |   |   |   |   |   |--- class:  <=50K
# |   |--- feature_4 >  7055.50
# |   |   |--- feature_0 <= 20.50
# |   |   |   |--- feature_4 <= 24559.50
# |   |   |   |   |--- class:  >50K
# |   |   |   |--- feature_4 >  24559.50
# |   |   |   |   |--- class:  <=50K
# |   |   |--- feature_0 >  20.50
# |   |   |   |--- feature_3 <= 1.50
# |   |   |   |   |--- feature_1 <= 202918.00
# |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |--- feature_1 >  202918.00
# |   |   |   |   |   |--- class:  <=50K
# |   |   |   |--- feature_3 >  1.50
# |   |   |   |   |--- feature_0 <= 61.50
# |   |   |   |   |   |--- feature_1 <= 24884.00
# |   |   |   |   |   |   |--- feature_4 <= 7565.50
# |   |   |   |   |   |   |   |--- feature_4 <= 7370.50
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_4 >  7370.50
# |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_4 >  7565.50
# |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |--- feature_1 >  24884.00
# |   |   |   |   |   |   |--- feature_6 <= 87.00
# |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 7565.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 7436.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  7436.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_4 >  7565.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |--- feature_6 >  87.00
# |   |   |   |   |   |   |   |--- feature_0 <= 36.50
# |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_0 >  36.50
# |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |--- feature_0 >  61.50
# |   |   |   |   |   |--- feature_3 <= 10.50
# |   |   |   |   |   |   |--- feature_4 <= 10585.50
# |   |   |   |   |   |   |   |--- feature_4 <= 9976.00
# |   |   |   |   |   |   |   |   |--- feature_6 <= 36.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 32.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  32.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |   |--- feature_6 >  36.50
# |   |   |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |   |--- feature_4 >  9976.00
# |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |--- feature_4 >  10585.50
# |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |--- feature_3 >  10.50
# |   |   |   |   |   |   |--- feature_4 <= 34569.00
# |   |   |   |   |   |   |   |--- class:  >50K
# |   |   |   |   |   |   |--- feature_4 >  34569.00
# |   |   |   |   |   |   |   |--- feature_4 <= 70654.50
# |   |   |   |   |   |   |   |   |--- class:  <=50K
# |   |   |   |   |   |   |   |--- feature_4 >  70654.50
# |   |   |   |   |   |   |   |   |--- class:  >50K

# %% [markdown]
# ### Does it help to normalize continuous values?

# %%
#Normalizing the data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
test_dec_tree=DecisionTreeClassifier().fit(X_train, y_train)

# %%
a = test_dec_tree.score(X_test, y_test)
print('Accuracy is: %', a*100)
# Out:
# Accuracy is: % 78.6831545327983

# %%
y_preds = test_dec_tree.predict(X_test)
print(classification_report(y_test, y_preds))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.86      0.86      0.86      9256
#         >50K       0.56      0.56      0.56      2955
#
#     accuracy                           0.79     12211
#    macro avg       0.71      0.71      0.71     12211
# weighted avg       0.79      0.79      0.79     12211

# %% [markdown]
# ## Try Deep Learning Model
#
# Requires "1-hot" class incoding

# %%
# output encodings
df["gt50k"] = df["class"].apply(lambda x: 1 if ">" in x else 0)
df["lte50k"] = df["class"].apply(lambda x: 1 if "<=" in x else 0)
df.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# 3      Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4      Married-civ-spouse      Prof-specialty            Wife   Black
# 5      Married-civ-spouse     Exec-managerial            Wife   White
# 6   Married-spouse-absent       Other-service   Not-in-family   Black
# 7      Married-civ-spouse     Exec-managerial         Husband   White
# 8           Never-married      Prof-specialty   Not-in-family   White
# 9      Married-civ-spouse     Exec-managerial         Husband   White
#
#        sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 0     Male          2174             0              40   United-States
# 1     Male             0             0              13   United-States
# 2     Male             0             0              40   United-States
# 3     Male             0             0              40   United-States
# 4   Female             0             0              40            Cuba
# 5   Female             0             0              40   United-States
# 6   Female             0             0              16         Jamaica
# 7     Male             0             0              45   United-States
# 8   Female         14084             0              50   United-States
# 9     Male          5178             0              40   United-States
#
#     class  sex-val  gt50k  lte50k
# 0   <=50K        1      0       1
# 1   <=50K        1      0       1
# 2   <=50K        1      0       1
# 3   <=50K        1      0       1
# 4   <=50K        0      0       1
# 5   <=50K        0      0       1
# 6   <=50K        0      0       1
# 7    >50K        1      1       0
# 8    >50K        0      1       0
# 9    >50K        1      1       0

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler

# %%
# Testing/Training Split
dy = df[["gt50k", "lte50k"]]
X_train, X_test, y_train, y_test = train_test_split(dft, dy)

# %%
#Normalizing the data
nnsc = StandardScaler()
X_train = nnsc.fit_transform(X_train)
X_test = nnsc.transform(X_test)

# %%
# Neural network
model = Sequential()
model.add(Dense(20, input_dim=7, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(2, activation='softmax'))
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                160
#
#  dense_1 (Dense)             (None, 16)                336
#
#  dense_2 (Dense)             (None, 2)                 34
#
# =================================================================
# Total params: 530
# Trainable params: 530
# Non-trainable params: 0
# _________________________________________________________________
# None
# 2022-06-02 12:41:15.603074: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train,validation_data = (X_test,y_test), epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.4202 - accuracy: 0.8082 - val_loss: 0.3716 - val_accuracy: 0.8318
# Epoch 2/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3802 - accuracy: 0.8252 - val_loss: 0.3659 - val_accuracy: 0.8335
# Epoch 3/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3764 - accuracy: 0.8274 - val_loss: 0.3652 - val_accuracy: 0.8344
# Epoch 4/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3748 - accuracy: 0.8274 - val_loss: 0.3645 - val_accuracy: 0.8347
# Epoch 5/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3739 - accuracy: 0.8280 - val_loss: 0.3644 - val_accuracy: 0.8339
# Epoch 6/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3731 - accuracy: 0.8292 - val_loss: 0.3646 - val_accuracy: 0.8329
# Epoch 7/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3726 - accuracy: 0.8294 - val_loss: 0.3641 - val_accuracy: 0.8329
# Epoch 8/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3719 - accuracy: 0.8295 - val_loss: 0.3627 - val_accuracy: 0.8342
# Epoch 9/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3711 - accuracy: 0.8300 - val_loss: 0.3624 - val_accuracy: 0.8333
# Epoch 10/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3708 - accuracy: 0.8304 - val_loss: 0.3618 - val_accuracy: 0.8339
# Epoch 11/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3702 - accuracy: 0.8302 - val_loss: 0.3618 - val_accuracy: 0.8329
# Epoch 12/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3695 - accuracy: 0.8301 - val_loss: 0.3631 - val_accuracy: 0.8328
# Epoch 13/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3687 - accuracy: 0.8312 - val_loss: 0.3621 - val_accuracy: 0.8323
# Epoch 14/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3683 - accuracy: 0.8316 - val_loss: 0.3620 - val_accuracy: 0.8337
# Epoch 15/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3678 - accuracy: 0.8320 - val_loss: 0.3619 - val_accuracy: 0.8345
# Epoch 16/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3675 - accuracy: 0.8315 - val_loss: 0.3608 - val_accuracy: 0.8356
# Epoch 17/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3669 - accuracy: 0.8328 - val_loss: 0.3615 - val_accuracy: 0.8351
# Epoch 18/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3664 - accuracy: 0.8329 - val_loss: 0.3612 - val_accuracy: 0.8352
# Epoch 19/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3662 - accuracy: 0.8324 - val_loss: 0.3618 - val_accuracy: 0.8373
# Epoch 20/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3661 - accuracy: 0.8329 - val_loss: 0.3608 - val_accuracy: 0.8356
# Epoch 21/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3657 - accuracy: 0.8331 - val_loss: 0.3605 - val_accuracy: 0.8365
# Epoch 22/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3656 - accuracy: 0.8331 - val_loss: 0.3612 - val_accuracy: 0.8353
# Epoch 23/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3651 - accuracy: 0.8334 - val_loss: 0.3601 - val_accuracy: 0.8351
# Epoch 24/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3652 - accuracy: 0.8344 - val_loss: 0.3613 - val_accuracy: 0.8373
# Epoch 25/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3650 - accuracy: 0.8333 - val_loss: 0.3617 - val_accuracy: 0.8368
# Epoch 26/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3648 - accuracy: 0.8338 - val_loss: 0.3625 - val_accuracy: 0.8341
# Epoch 27/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3645 - accuracy: 0.8332 - val_loss: 0.3607 - val_accuracy: 0.8370
# Epoch 28/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3645 - accuracy: 0.8331 - val_loss: 0.3606 - val_accuracy: 0.8366
# Epoch 29/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3643 - accuracy: 0.8334 - val_loss: 0.3606 - val_accuracy: 0.8361
# Epoch 30/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3644 - accuracy: 0.8341 - val_loss: 0.3606 - val_accuracy: 0.8365
# Epoch 31/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3640 - accuracy: 0.8334 - val_loss: 0.3623 - val_accuracy: 0.8359
# Epoch 32/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3640 - accuracy: 0.8340 - val_loss: 0.3612 - val_accuracy: 0.8347
# Epoch 33/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3639 - accuracy: 0.8343 - val_loss: 0.3618 - val_accuracy: 0.8347
# Epoch 34/100
# 573/573 [==============================] - 1s 2ms/step - loss: 0.3635 - accuracy: 0.8337 - val_loss: 0.3617 - val_accuracy: 0.8355
# Epoch 35/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3637 - accuracy: 0.8339 - val_loss: 0.3616 - val_accuracy: 0.8365
# Epoch 36/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3634 - accuracy: 0.8346 - val_loss: 0.3607 - val_accuracy: 0.8355
# Epoch 37/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3635 - accuracy: 0.8338 - val_loss: 0.3630 - val_accuracy: 0.8364
# Epoch 38/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3634 - accuracy: 0.8334 - val_loss: 0.3628 - val_accuracy: 0.8354
# Epoch 39/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3632 - accuracy: 0.8336 - val_loss: 0.3611 - val_accuracy: 0.8356
# Epoch 40/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3630 - accuracy: 0.8345 - val_loss: 0.3625 - val_accuracy: 0.8344
# Epoch 41/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3636 - accuracy: 0.8338 - val_loss: 0.3612 - val_accuracy: 0.8351
# Epoch 42/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3631 - accuracy: 0.8334 - val_loss: 0.3615 - val_accuracy: 0.8356
# Epoch 43/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3628 - accuracy: 0.8345 - val_loss: 0.3617 - val_accuracy: 0.8371
# Epoch 44/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3632 - accuracy: 0.8345 - val_loss: 0.3615 - val_accuracy: 0.8342
# Epoch 45/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3627 - accuracy: 0.8351 - val_loss: 0.3614 - val_accuracy: 0.8361
# Epoch 46/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3628 - accuracy: 0.8340 - val_loss: 0.3618 - val_accuracy: 0.8355
# Epoch 47/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3627 - accuracy: 0.8345 - val_loss: 0.3605 - val_accuracy: 0.8362
# Epoch 48/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3628 - accuracy: 0.8351 - val_loss: 0.3604 - val_accuracy: 0.8360
# Epoch 49/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3625 - accuracy: 0.8352 - val_loss: 0.3618 - val_accuracy: 0.8370
# Epoch 50/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3626 - accuracy: 0.8341 - val_loss: 0.3604 - val_accuracy: 0.8359
# Epoch 51/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3626 - accuracy: 0.8337 - val_loss: 0.3627 - val_accuracy: 0.8359
# Epoch 52/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3626 - accuracy: 0.8347 - val_loss: 0.3603 - val_accuracy: 0.8348
# Epoch 53/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3620 - accuracy: 0.8343 - val_loss: 0.3606 - val_accuracy: 0.8363
# Epoch 54/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3622 - accuracy: 0.8347 - val_loss: 0.3598 - val_accuracy: 0.8370
# Epoch 55/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3623 - accuracy: 0.8350 - val_loss: 0.3619 - val_accuracy: 0.8353
# Epoch 56/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3622 - accuracy: 0.8343 - val_loss: 0.3618 - val_accuracy: 0.8352
# Epoch 57/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3620 - accuracy: 0.8344 - val_loss: 0.3613 - val_accuracy: 0.8351
# Epoch 58/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3623 - accuracy: 0.8351 - val_loss: 0.3614 - val_accuracy: 0.8352
# Epoch 59/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3623 - accuracy: 0.8349 - val_loss: 0.3614 - val_accuracy: 0.8349
# Epoch 60/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3620 - accuracy: 0.8343 - val_loss: 0.3604 - val_accuracy: 0.8372
# Epoch 61/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3618 - accuracy: 0.8346 - val_loss: 0.3602 - val_accuracy: 0.8362
# Epoch 62/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3621 - accuracy: 0.8335 - val_loss: 0.3606 - val_accuracy: 0.8357
# Epoch 63/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3620 - accuracy: 0.8336 - val_loss: 0.3612 - val_accuracy: 0.8358
# Epoch 64/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3619 - accuracy: 0.8346 - val_loss: 0.3605 - val_accuracy: 0.8356
# Epoch 65/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3620 - accuracy: 0.8340 - val_loss: 0.3620 - val_accuracy: 0.8349
# Epoch 66/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3618 - accuracy: 0.8346 - val_loss: 0.3604 - val_accuracy: 0.8366
# Epoch 67/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3621 - accuracy: 0.8342 - val_loss: 0.3599 - val_accuracy: 0.8361
# Epoch 68/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3619 - accuracy: 0.8340 - val_loss: 0.3603 - val_accuracy: 0.8370
# Epoch 69/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3615 - accuracy: 0.8350 - val_loss: 0.3607 - val_accuracy: 0.8367
# Epoch 70/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3614 - accuracy: 0.8343 - val_loss: 0.3590 - val_accuracy: 0.8366
# Epoch 71/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3616 - accuracy: 0.8345 - val_loss: 0.3610 - val_accuracy: 0.8362
# Epoch 72/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3615 - accuracy: 0.8351 - val_loss: 0.3618 - val_accuracy: 0.8357
# Epoch 73/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3615 - accuracy: 0.8343 - val_loss: 0.3600 - val_accuracy: 0.8360
# Epoch 74/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3615 - accuracy: 0.8340 - val_loss: 0.3594 - val_accuracy: 0.8358
# Epoch 75/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3611 - accuracy: 0.8346 - val_loss: 0.3605 - val_accuracy: 0.8366
# Epoch 76/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3613 - accuracy: 0.8340 - val_loss: 0.3601 - val_accuracy: 0.8352
# Epoch 77/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3613 - accuracy: 0.8343 - val_loss: 0.3604 - val_accuracy: 0.8351
# Epoch 78/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3613 - accuracy: 0.8348 - val_loss: 0.3587 - val_accuracy: 0.8365
# Epoch 79/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3610 - accuracy: 0.8358 - val_loss: 0.3585 - val_accuracy: 0.8372
# Epoch 80/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3611 - accuracy: 0.8345 - val_loss: 0.3590 - val_accuracy: 0.8370
# Epoch 81/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3610 - accuracy: 0.8349 - val_loss: 0.3592 - val_accuracy: 0.8370
# Epoch 82/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3608 - accuracy: 0.8349 - val_loss: 0.3588 - val_accuracy: 0.8375
# Epoch 83/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3612 - accuracy: 0.8354 - val_loss: 0.3602 - val_accuracy: 0.8342
# Epoch 84/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3608 - accuracy: 0.8350 - val_loss: 0.3600 - val_accuracy: 0.8374
# Epoch 85/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3611 - accuracy: 0.8344 - val_loss: 0.3590 - val_accuracy: 0.8368
# Epoch 86/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3607 - accuracy: 0.8343 - val_loss: 0.3612 - val_accuracy: 0.8365
# Epoch 87/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3610 - accuracy: 0.8339 - val_loss: 0.3586 - val_accuracy: 0.8365
# Epoch 88/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3606 - accuracy: 0.8347 - val_loss: 0.3584 - val_accuracy: 0.8365
# Epoch 89/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3604 - accuracy: 0.8343 - val_loss: 0.3591 - val_accuracy: 0.8343
# Epoch 90/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3605 - accuracy: 0.8340 - val_loss: 0.3588 - val_accuracy: 0.8383
# Epoch 91/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3606 - accuracy: 0.8355 - val_loss: 0.3590 - val_accuracy: 0.8356
# Epoch 92/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3605 - accuracy: 0.8342 - val_loss: 0.3575 - val_accuracy: 0.8385
# Epoch 93/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3603 - accuracy: 0.8351 - val_loss: 0.3582 - val_accuracy: 0.8368
# Epoch 94/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3603 - accuracy: 0.8340 - val_loss: 0.3591 - val_accuracy: 0.8369
# Epoch 95/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3602 - accuracy: 0.8345 - val_loss: 0.3603 - val_accuracy: 0.8342
# Epoch 96/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3602 - accuracy: 0.8354 - val_loss: 0.3601 - val_accuracy: 0.8346
# Epoch 97/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3602 - accuracy: 0.8340 - val_loss: 0.3581 - val_accuracy: 0.8383
# Epoch 98/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3602 - accuracy: 0.8342 - val_loss: 0.3588 - val_accuracy: 0.8365
# Epoch 99/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3602 - accuracy: 0.8353 - val_loss: 0.3580 - val_accuracy: 0.8375
# Epoch 100/100
# 573/573 [==============================] - 1s 1ms/step - loss: 0.3599 - accuracy: 0.8352 - val_loss: 0.3574 - val_accuracy: 0.8366

# %%
y_pred = model.predict(X_test)
# Out:
# 382/382 [==============================] - 0s 594us/step

# %%
#Converting 1-hot predictions to class label
pred = list()
for i in range(len(y_pred)):
    pred.append(np.argmax(y_pred[i]))

# %%
# Because 1-hot is (0,1), this is also class label index
test = list(y_test.lte50k)

# %%
from sklearn.metrics import accuracy_score
a = accuracy_score(pred,test)
print('Accuracy is: %', a*100)
# Out:
# Accuracy is: % 83.66227172221767

# %%
print(classification_report(test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.50      0.60      2937
#            1       0.86      0.94      0.90      9274
#
#     accuracy                           0.84     12211
#    macro avg       0.80      0.72      0.75     12211
# weighted avg       0.83      0.84      0.82     12211

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss']) 
plt.plot(history.history['val_loss']) 
plt.title('Model loss') 
plt.ylabel('Loss') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper left') 
plt.show()

# %% [markdown]
# ## Save trained models for use in prediction algorithms

# %%
from joblib import dump, load
dump(dec_tree, "decision_tree.pkl")
dump(model, "neural_net.pkl")
dump(nnsc, "neural_net_scaler.pkl")
# Out:
# INFO:tensorflow:Assets written to: ram://33f7080d-26e3-46b6-b8fc-4cc65c3a6e2e/assets
# ['neural_net_scaler.pkl']

# %% [markdown]
# # Input Data Vetting

# %%
vdata = [["Feature", "count", "mean", "std", "min", "25%", "50%", "75%", "max"]]
for h in features:
    row = []
    row.append(h)
    print("#"*25)
    x = df[h].describe()
    print(x)
    row.extend(list(x))
    vdata.append(row)
# Out:
# #########################
# count    48842.000000
# mean        38.643585
# std         13.710510
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64
# #########################
# count    4.884200e+04
# mean     1.896641e+05
# std      1.056040e+05
# min      1.228500e+04
# 25%      1.175505e+05
# 50%      1.781445e+05
# 75%      2.376420e+05
# max      1.490400e+06
# Name: fnlwgt, dtype: float64
# #########################
# count    48842.000000
# mean         0.668482
# std          0.470764
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: sex-val, dtype: float64
# #########################
# count    48842.000000
# mean        10.078089
# std          2.570973
# min          1.000000
# 25%          9.000000
# 50%         10.000000
# 75%         12.000000
# max         16.000000
# Name: education-num, dtype: float64
# #########################
# count    48842.000000
# mean      1079.067626
# std       7452.019058
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      99999.000000
# Name: capital-gain, dtype: float64
# #########################
# count    48842.000000
# mean        87.502314
# std        403.004552
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       4356.000000
# Name: capital-loss, dtype: float64
# #########################
# count    48842.000000
# mean        40.422382
# std         12.391444
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours-per-week, dtype: float64

# %%
import csv
with open("../data/feature_vetting.csv", "w") as outfile:
    wrtr = csv.writer(outfile)
    wrtr.writerows(vdata)
